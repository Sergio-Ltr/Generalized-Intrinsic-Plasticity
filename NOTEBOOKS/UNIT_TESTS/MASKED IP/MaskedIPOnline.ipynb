# %% [markdown]
# # Bimodal Setup unit test

# %%
import sys  
sys.path.insert(1, './../../../../ESN-IP/SOURCES/.')

import random

random.seed(10)

# %%
from Reservoir import Reservoir
from ESN import EchoStateNetwork
from IPReservoir import IPReservoir
from IPMask import IPMask
from DATA import MG17

# %%
import torch
import numpy
import random

# %%
data = MG17(True, [80,0,20])

X_TR, Y_TR = data.TR()
X_TS, Y_TS = data.TS()

# %%
N = 50

# %%
vanilla_reservoir = IPReservoir(N=N, bias = False, desired_rho=0.96)

# %% [markdown]
# ## Unimodal

# %%
unimodal_reservoir = IPReservoir(N=N, bias = False, desired_rho=0.1, mask=IPMask.gaussian(N, 0.25))

# %%
unimodal_reservoir.plot_neural_activity(X_TS, )

# %%
#bimodal_reservoir.plot_neural_activity(X_TS, )

# %%
unimodal_reservoir.plot_neural_activity(X_TS)

# %%
unimodal_reservoir.IP_online(X_TR, eta=0.0000025, epochs=10, verbose=True, debug=False)

# %%
unimodal_reservoir.plot_neural_activity(X_TS)

# %%
unimodal_reservoir.rescale_weights(0.95)

# %%
unimodal_reservoir.plot_neural_activity(X_TS)

# %%
unimodal_reservoir.b
# Out:
# tensor([-0.6535, -0.0622,  0.9524,  0.3962,  0.2003, -0.1804, -0.0030,  1.1737,
#         -1.2195, -0.1373, -1.0637, -1.1904, -0.4896, -0.2294, -0.0165,  1.1685,
#          0.7405,  0.9516,  0.0815, -0.3411, -0.4766,  0.1189,  0.6864,  0.0971,
#          1.0363,  0.7417,  0.6864, -0.1564,  0.3101,  0.0843,  0.8358, -0.9101,
#          0.4001,  0.9775, -1.1907, -0.1478,  0.9270,  0.5899,  0.9918, -0.1396,
#         -0.9042, -0.6699,  1.1587,  1.0916,  0.8044,  0.6921, -0.6236, -0.9912,
#         -0.0421,  1.0633])

# %%
unimodal_reservoir.a
# Out:
# tensor([1.1811, 1.1811, 1.1811, 1.1811, 1.1811, 1.1811, 1.1811, 1.1811, 1.1811,
#         1.1811, 1.1811, 1.1811, 1.1811, 1.1811, 1.1811, 1.1811, 1.1811, 1.1811,
#         1.1811, 1.1811, 1.1811, 1.1811, 1.1811, 1.1811, 1.1811, 1.1811, 1.1811,
#         1.1811, 1.1811, 1.1811, 1.1811, 1.1811, 1.1811, 1.1811, 1.1811, 1.1811,
#         1.1811, 1.1811, 1.1811, 1.1811, 1.1811, 1.1811, 1.1811, 1.1811, 1.1811,
#         1.1811, 1.1811, 1.1811, 1.1811, 1.1811])

# %% [markdown]
# ## Bimodal

# %%
bimodal_reservoir = IPReservoir(N=N, bias = False, desired_rho=0.1, mask=IPMask.bimodal(N))

# %%
bimodal_reservoir.plot_neural_activity(X_TS)

# %%
bimodal_reservoir.IP_online(X_TR, eta=0.0000005, epochs=5, verbose=True, debug=False)

# %%
bimodal_reservoir.plot_neural_activity(X_TS)

# %%
unimodal_reservoir.rescale_weights(0.95)

# %%
bimodal_reservoir.plot_neural_activity(X_TS)

# %%
bimodal_reservoir.a
# Out:
# tensor([1.0188, 1.0188, 1.0188, 1.0188, 1.0188, 1.0188, 1.0188, 1.0188, 1.0188,
#         1.0188, 1.0188, 1.0188, 1.0188, 1.0188, 1.0188, 1.0188, 1.0188, 1.0188,
#         1.0188, 1.0188, 1.0188, 1.0188, 1.0188, 1.0188, 1.0188, 1.0188, 1.0188,
#         1.0188, 1.0188, 1.0188, 1.0188, 1.0188, 1.0188, 1.0188, 1.0188, 1.0188,
#         1.0188, 1.0188, 1.0188, 1.0188, 1.0188, 1.0188, 1.0188, 1.0188, 1.0188,
#         1.0188, 1.0188, 1.0188, 1.0188, 1.0188])

# %% [markdown]
# ## Trimodal

# %%
trimodal_reservoir = IPReservoir(N=N, bias = False, desired_rho=0.1, mask=IPMask.trimodal(N))

# %%
trimodal_reservoir.plot_neural_activity(X_TS)

# %%
trimodal_reservoir.IP_online(X_TR, eta=0.000005, epochs=5, verbose=True, debug=False)

# %%
trimodal_reservoir.plot_neural_activity(X_TS, transient=0)

# %%
trimodal_reservoir.rescale_weights(0.96)

# %%
trimodal_reservoir.plot_neural_activity(X_TS, transient=0)

# %%
trimodal_reservoir.a
# Out:
# tensor([1.1812, 1.1812, 1.1812, 1.1812, 1.1812, 1.1812, 1.1812, 1.1812, 1.1812,
#         1.1812, 1.1812, 1.1812, 1.1812, 1.1812, 1.1812, 1.1812, 1.1812, 1.1812,
#         1.1812, 1.1812, 1.1812, 1.1812, 1.1812, 1.1812, 1.1812, 1.1812, 1.1812,
#         1.1812, 1.1812, 1.1812, 1.1812, 1.1812, 1.1812, 1.1812, 1.1812, 1.1812,
#         1.1812, 1.1812, 1.1812, 1.1812, 1.1812, 1.1812, 1.1812, 1.1812, 1.1812,
#         1.1812, 1.1812, 1.1812, 1.1812, 1.1812])

# %%
trimodal_reservoir.b
# Out:
# tensor([-0.2664,  0.4241, -0.5155, -0.2516,  0.3231, -0.1185,  0.4453,  0.1710,
#          0.5286,  0.4016,  0.5446, -0.4387, -0.0792, -0.1203, -0.3592, -0.3137,
#          0.1091,  2.2774, -1.0084,  1.0286, -0.2489,  0.4473, -0.7843,  0.7606,
#          0.1035,  0.5466, -0.7972,  1.5986, -0.8849,  1.2236, -0.5404,  1.0833,
#         -0.6813,  1.6709, -0.5286,  1.0508, -1.7518,  0.5687, -2.2244,  1.5374,
#         -1.0605,  1.7986, -0.6793,  1.5315, -0.2426,  1.8384, -0.9772,  1.2289,
#         -0.0428,  0.8616])

# %% [markdown]
# ## Estrinsic Metrics

# %%
from ESN import EchoStateNetwork

from Metrics import *
Error = MSE(True)

# %%
esn = EchoStateNetwork(vanilla_reservoir)

esn.train(X_TR, Y=Y_TR, transient=100)
y_pred = esn.predict(X_TS)
Error.evaluate(y_pred, Y_TS)
# Out:
# Reservoir warmed up with the first 100 time steps
# tensor(3.4426e-07, dtype=torch.float64)

# %%
esn = EchoStateNetwork(unimodal_reservoir)
esn.train(X_TR, Y=Y_TR, transient=100)
y_pred = esn.predict(X_TS)
Error.evaluate(y_pred, Y_TS)
# Out:
# Reservoir warmed up with the first 100 time steps
# tensor(4.9079e-07, dtype=torch.float64)

# %%
esn = EchoStateNetwork(bimodal_reservoir)
esn.train(X_TR, Y=Y_TR, transient=100)
y_pred = esn.predict(X_TS)
Error.evaluate(y_pred, Y_TS)
# Out:
# Reservoir warmed up with the first 100 time steps
# tensor(1.4423e-06, dtype=torch.float64)

# %%
esn = EchoStateNetwork(trimodal_reservoir)
esn.train(X_TR, Y=Y_TR, transient=100)
y_pred = esn.predict(X_TS)
Error.evaluate(y_pred, Y_TS)
# Out:
# Reservoir warmed up with the first 100 time steps
# tensor(2.9223e-07, dtype=torch.float64)

# %% [markdown]
# ## Intrinsic Metrics

# %%
MemoryCapacity = MC()
DeviationFromLinearity = DeltaPhi()
EffectiveDimension = Neff()
LambdaMax = MLLE(X_TS)

# %%
EffectiveDimension.evaluate(vanilla_reservoir)
# Out:
# 1.6722397761592247

# %%
EffectiveDimension_row = [EffectiveDimension.evaluate(unimodal_reservoir), EffectiveDimension.evaluate(bimodal_reservoir), EffectiveDimension.evaluate(trimodal_reservoir)]

# %%
EffectiveDimension_row
# Out:
# [3.806784845810123, 1.0709873814873687, 1.6943981285588894]

# %%
DeviationFromLinearity.evaluate(vanilla_reservoir)
# Out:
# 0.25888823745935313

# %%
DeltaPhi_row = [DeviationFromLinearity.evaluate(unimodal_reservoir),DeviationFromLinearity.evaluate(bimodal_reservoir), DeviationFromLinearity.evaluate(trimodal_reservoir)]

# %%
DeltaPhi_row
# Out:
# [0.09122082739135111, 0.04682382813700075, 0.26468273290484906]

# %%
LambdaMax.evaluate(vanilla_reservoir)
# Out:
# -0.41688886

# %%
LambdaMax_row = [LambdaMax.evaluate(unimodal_reservoir),LambdaMax.evaluate(bimodal_reservoir), LambdaMax.evaluate(trimodal_reservoir)]

# %%
LambdaMax_row
# Out:
# [0.05011537, -2.758778, -0.22240448]

# %%
MemoryCapacity.evaluate(vanilla_reservoir)
# Out:
# tensor(7.4839)

# %%
MC_row = [MemoryCapacity.evaluate(unimodal_reservoir),MemoryCapacity.evaluate(bimodal_reservoir), MemoryCapacity.evaluate(trimodal_reservoir)]

# %%
MC_row
# Out:
# [tensor(10.8717), tensor(4.6643), tensor(6.6144)]
