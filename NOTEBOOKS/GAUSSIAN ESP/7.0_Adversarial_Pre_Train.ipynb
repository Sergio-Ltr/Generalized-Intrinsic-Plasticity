# %%
import sys  
sys.path.insert(1, './../../../ESN-IP/IP/.')

import random

random.seed(10)

from DATA import NARMA10

data = NARMA10(True, [80,0,20])

X_TR, Y_TR = data.TR()
X_VAL, Y_VAL = data.VAL()
X_TS, Y_TS = data.TS()

# %%
from IPReservoir import IPReservoir
from ESN import Reservoir, EchoStateNetwork
from IntrinsicPlasticity import IPMask, IPDistribution

N_UNITS = 250
W_range=(-0.5, 0.5)
bimodal_reservoir = IPReservoir(N = N_UNITS, desired_rho=0.75, bias = True, W_range=W_range, bias_range=[-0.1, 0.1], mask=IPMask.trimodal(N_UNITS, 7/10, 0.45, 0.15, 0.7, apply_activation=True))

# %%
bimodal_reservoir.rho()
# Out:
# tensor(0.7500)

# %%
bimodal_reservoir.pre_train(X_TS, 0, 0)
bimodal_reservoir.predict(X_TS, save_gradients=False, save_states=True)
bimodal_reservoir.plot_neural_activity()

# %%
bimodal_reservoir.reset_initial_state()

# %%
bimodal_reservoir.KL(X_TS[100:None])
# Out:
# tensor(0.1456)

# %%
bimodal_reservoir.pre_train(X_TR, epochs=5, eta=0.00000025)
# Out:
# - Epoch: 1) | KL Divergence value: 0.13609424233436584. | Spectral radius: 0.7523983120918274
# - Epoch: 2) | KL Divergence value: 0.1284395456314087. | Spectral radius: 0.7558995485305786
# - Epoch: 3) | KL Divergence value: 0.12328831106424332. | Spectral radius: 0.7607994675636292
# - Epoch: 4) | KL Divergence value: 0.12061844021081924. | Spectral radius: 0.7674078941345215
# - Epoch: 5) | KL Divergence value: 0.12014643102884293. | Spectral radius: 0.7768452763557434

# %%
bimodal_reservoir.pre_train(X_TS, 0, 0)
bimodal_reservoir.predict(X_TS, save_gradients=False, save_states=True)
bimodal_reservoir.plot_neural_activity()

# %%
bimodal_reservoir.pre_train(X_TR, epochs=5, eta=0.000000125)
# Out:
# - Epoch: 1) | KL Divergence value: 0.12050092220306396. | Spectral radius: 0.7831659317016602
# - Epoch: 2) | KL Divergence value: 0.12134423851966858. | Spectral radius: 0.7942991256713867
# - Epoch: 3) | KL Divergence value: 0.12250424921512604. | Spectral radius: 0.8070697784423828
# - Epoch: 4) | KL Divergence value: 0.12391410022974014. | Spectral radius: 0.8211018443107605
# - Epoch: 5) | KL Divergence value: 0.12550589442253113. | Spectral radius: 0.8389394283294678

# %%
bimodal_reservoir.pre_train(X_TS, 0, 0)
bimodal_reservoir.predict(X_TS, save_gradients=False, save_states=True)
bimodal_reservoir.plot_neural_activity()

# %%
bimodal_reservoir.pre_train(X_TR, epochs=5, eta=0.000000125)
# Out:
# - Epoch: 1) | KL Divergence value: 0.13063471019268036. | Spectral radius: 0.9150738716125488
# - Epoch: 2) | KL Divergence value: 0.13232620060443878. | Spectral radius: 0.9475986361503601
# - Epoch: 3) | KL Divergence value: 0.13394634425640106. | Spectral radius: 0.9855574369430542
# - Epoch: 4) | KL Divergence value: 0.1354883760213852. | Spectral radius: 1.0309624671936035
# - Epoch: 5) | KL Divergence value: 0.13695290684700012. | Spectral radius: 1.08012056350708

# %%
bimodal_reservoir.pre_train(X_TR, epochs=5, eta=0.00000005)
# Out:
# - Epoch: 1) | KL Divergence value: 0.12609605491161346. | Spectral radius: 0.8474748134613037
# - Epoch: 2) | KL Divergence value: 0.12678588926792145. | Spectral radius: 0.8564746379852295
# - Epoch: 3) | KL Divergence value: 0.12748491764068604. | Spectral radius: 0.8659461140632629
# - Epoch: 4) | KL Divergence value: 0.12818941473960876. | Spectral radius: 0.8759084939956665
# - Epoch: 5) | KL Divergence value: 0.12889568507671356. | Spectral radius: 0.8863881826400757

# %%
bimodal_reservoir.pre_train(X_TS, 0, 0)
bimodal_reservoir.predict(X_TS, save_gradients=False, save_states=True)
bimodal_reservoir.plot_neural_activity()

# %%
bimodal_reservoir.pre_train(X_TR, epochs=5, eta=-0.000000125)
# Out:
# - Epoch: 1) | KL Divergence value: 0.13753297924995422. | Spectral radius: 1.1109815835952759
# - Epoch: 2) | KL Divergence value: 0.13611340522766113. | Spectral radius: 1.0594574213027954
# - Epoch: 3) | KL Divergence value: 0.13462041318416595. | Spectral radius: 1.0118719339370728
# - Epoch: 4) | KL Divergence value: 0.13304992020130157. | Spectral radius: 0.9687445759773254
# - Epoch: 5) | KL Divergence value: 0.13140349090099335. | Spectral radius: 0.9337447881698608

# %%
bimodal_reservoir.pre_train(X_TR, epochs=5, eta=+0.00000005)
# Out:
# - Epoch: 1) | KL Divergence value: 0.12385419756174088. | Spectral radius: 0.9162057638168335
# - Epoch: 2) | KL Divergence value: 0.12435849756002426. | Spectral radius: 0.9264146685600281
# - Epoch: 3) | KL Divergence value: 0.12484867870807648. | Spectral radius: 0.9370847940444946
# - Epoch: 4) | KL Divergence value: 0.12532496452331543. | Spectral radius: 0.9482338428497314
# - Epoch: 5) | KL Divergence value: 0.12578809261322021. | Spectral radius: 0.9598872065544128

# %%
bimodal_reservoir.de_fi()
# Out:
# 0.35385884848406574

# %%
bimodal_reservoir.LCE(X_TS)
# Out:
# -0.09843796

# %%
esn = EchoStateNetwork(bimodal_reservoir)

# %%
esn.train(X_TR, Y_TR, 0)
# Out:
# Reservoir warmed up with the first 100 time steps
# array([0.265625  , 0.265625  , 0.234375  , ..., 0.28515625, 0.26757812,
#        0.21679688], dtype=float32)

# %%
from Metrics import MSE

# %%
esn.evaluate(X_TS,Y_TS,metric=MSE(), plot=True)
# Out:
# tensor(0.0221, dtype=torch.float64)

# %%
from IPReservoir import IPReservoir
from ESN import Reservoir, EchoStateNetwork
from IntrinsicPlasticity import IPMask, IPDistribution

N_UNITS = 250
W_range=(-0.5, 0.5)
res = IPReservoir(N = N_UNITS, desired_rho=0.75, bias = True, W_range=W_range, bias_range=[-0.1, 0.1], mask=IPMask.trimodal(N_UNITS, 7/10, 0.45, 0.15, 0.7, apply_activation=True))

# %%
res.pre_train(X_TS, 0, 0)
res.predict(X_TS, save_gradients=False, save_states=True)
res.plot_neural_activity()

# %%
esn = EchoStateNetwork(res)

# %%
res.reset_initial_state()

# %%
esn.train(X_TR, Y_TR, 0)
# Out:
# Reservoir warmed up with the first 100 time steps
# array([0.2642517 , 0.24295044, 0.23422241, ..., 0.28477478, 0.26330566,
#        0.23953247], dtype=float32)

# %%
esn.evaluate(X_TS, Y_TS, metric=MSE(), plot=True)
# Out:
# tensor(0.0221, dtype=torch.float64)

# %%
res.de_fi()
# Out:
# 0.04605644126036271

# %%
res.LCE(X_TS)
# Out:
# -0.29716113

# %% [markdown]
# # EXPERIMENTS WITH OTHER STUFF

# %%
bimodal_dist = IPMask.bimodal(250).sample(2000)

# %%
import numpy as np    
import matplotlib.pyplot as plt

x = bimodal_dist.flatten().numpy()
y = bimodal_reservoir.activation(bimodal_dist).flatten().numpy()

xs = np.linspace(y.min(), y.max(), 500)
ys = np.zeros_like(xs)

#plt.set_title(f"Activations of neuron {i+1}")
plt.plot(xs, ys)
plt.hist([x, y],  bins="fd", label=['Actual', 'Target'])
plt.xlabel("x")
plt.ylabel("f(x)")
plt.show()

# %%
bimodal_dist = IPMask.normalMask(250).sample(2000)

# %%
import numpy as np    
import matplotlib.pyplot as plt

x = bimodal_dist.flatten().numpy()
y = bimodal_reservoir.activation(bimodal_dist).flatten().numpy()

xs = np.linspace(y.min(), y.max(), 500)
ys = np.zeros_like(xs)

#plt.set_title(f"Activations of neuron {i+1}")
plt.plot(xs, ys)
plt.hist([x, y],  bins="fd", label=['Actual', 'Target'])
plt.xlabel("x")
plt.ylabel("f(x)")
plt.show()

# %%
x_bim = IPMask.bimodal(250, 0.08, 0.92).sample(2000)
y_bim = IPMask.bimodal(250, 0.05, 0.7259).sample(2000)

# %%
import numpy as np    
import matplotlib.pyplot as plt

x = bimodal_reservoir.activation(x_bim).flatten().numpy()
y = y_bim.flatten().numpy()

xs = np.linspace(y.min(), y.max(), 500)
ys = np.zeros_like(xs)

#plt.set_title(f"Activations of neuron {i+1}")
plt.plot(xs, ys)
plt.hist([x, y],  bins="fd", label=['Actual', 'Target'])
plt.xlabel("x")
plt.ylabel("f(x)")
plt.show()

# %%
import torch
bimodal_reservoir.activation(torch.tensor([0.92]))
# Out:
# tensor([0.7259])

# %%
x_bim = IPMask.trimodal(N_UNITS, 7/10, 0.45, 0.15, 0.92).sample(5000)
y_bim = IPMask.trimodal(N_UNITS, 7/10, 0.45, 0.1, 0.7259).sample(5000)

import numpy as np    
import matplotlib.pyplot as plt

x = bimodal_reservoir.activation(x_bim).flatten().numpy()
y = y_bim.flatten().numpy()

xs = np.linspace(y.min(), y.max(), 500)
ys = np.zeros_like(xs)

#plt.set_title(f"Activations of neuron {i+1}")
plt.plot(xs, ys)
plt.hist([x, y],  bins="fd", label=['Actual', 'Target'])
plt.xlabel("x")
plt.ylabel("f(x)")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 x_bim = IPMask.trimodal(N_UNITS, 7/10, 0.45, 0.15, 0.92).sample(5000)
#       2 y_bim = IPMask.trimodal(N_UNITS, 7/10, 0.45, 0.1, 0.7259).sample(5000)
#       4 import numpy as np
#
# NameError: name 'IPMask' is not defined

# %%
KL= torch.nn.KLDivLoss(reduction="batchmean", log_target = True)

# %%
x_bim = IPMask.trimodal(N_UNITS, 7/10, 0.45, 0.15, 0.92).sample(2000)
y_bim = IPMask.trimodal(N_UNITS, 7/10, 0.45, 0.1, 0.7259).sample(2000)

import numpy as np    
import matplotlib.pyplot as plt

x = bimodal_reservoir.activation(x_bim).flatten().numpy()
y = y_bim.flatten().numpy()

xs = np.linspace(y.min(), y.max(), 500)
ys = np.zeros_like(xs)

#plt.set_title(f"Activations of neuron {i+1}")
plt.plot(xs, ys)
plt.hist([x, y],  bins="fd", label=['Actual', 'Target'])
plt.xlabel("x")
plt.ylabel("f(x)")
plt.show()

print(KL(torch.Tensor(x), torch.Tensor(y)))
# Out:
# tensor(0.1631)

# %%
KL(torch.Tensor(x), torch.Tensor(y))
# Out:
# tensor(0.1535)

# %%
x_bim = IPMask.gaussian(N_UNITS, 0.3, 0.0).sample(5000)
y_bim = IPMask.gaussian(N_UNITS, 0.3, 0.0).sample(5000)

import numpy as np    
import matplotlib.pyplot as plt

x = bimodal_reservoir.activation(x_bim).flatten().numpy()
y = y_bim.flatten().numpy()

xs = np.linspace(y.min(), y.max(), 500)
ys = np.zeros_like(xs)

#plt.set_title(f"Activations of neuron {i+1}")
plt.plot(xs, ys)
plt.hist([x, y],  bins="fd", label=['Actual', 'Target'])
plt.xlabel("x")
plt.ylabel("f(x)")
plt.show()

print(KL(torch.Tensor(x), torch.Tensor(y)))
# Out:
# tensor(0.0940)

# %%
from IPReservoir import IPReservoir
from ESN import Reservoir
from IntrinsicPlasticity import IPMask, IPDistribution

N_UNITS = 250
W_range=(-0.5, 0.5)
ip_reservoir = IPReservoir(N = N_UNITS, desired_rho=0.96, bias = False, mask=IPMask.gaussian(N_UNITS, 0.3, 0.0))

# %%
ip_reservoir.pre_train(X_TR, 0, 0)
ip_reservoir.predict(X_TR, save_gradients=False, save_states=True)
ip_reservoir.plot_neural_activity()

# %%
ip_reservoir.pre_train(X_TR, epochs=5, eta=-0.000001)
# Out:
# - Epoch: 1) | KL Divergence value: 0.06486885249614716. | Spectral radius: 0.9464191794395447
# - Epoch: 2) | KL Divergence value: 0.05774509906768799. | Spectral radius: 0.934735894203186
# - Epoch: 3) | KL Divergence value: 0.05355340987443924. | Spectral radius: 0.9239922761917114
# - Epoch: 4) | KL Divergence value: 0.05074622482061386. | Spectral radius: 0.9137950539588928
# - Epoch: 5) | KL Divergence value: 0.04872686788439751. | Spectral radius: 0.9038864970207214

# %%
ip_reservoir.pre_train(X_TR, epochs=5, eta=0.000001)
# Out:
# - Epoch: 1) | KL Divergence value: 0.05074271187186241. | Spectral radius: 0.9137960076332092
# - Epoch: 2) | KL Divergence value: 0.053540028631687164. | Spectral radius: 0.9239932894706726
# - Epoch: 3) | KL Divergence value: 0.05770384147763252. | Spectral radius: 0.9347318410873413
# - Epoch: 4) | KL Divergence value: 0.06476099044084549. | Spectral radius: 0.9464123249053955
# - Epoch: 5) | KL Divergence value: 0.07786300778388977. | Spectral radius: 0.9599758386611938

# %%
ip_reservoir.pre_train(X_TR, 0, 0)
ip_reservoir.predict(X_TR, save_gradients=False, save_states=True)
ip_reservoir.plot_neural_activity()

# %%
ip_reservoir.rescale_weights(0.8)

# %%
ip_reservoir.pre_train(X_TR, 0, 0)
ip_reservoir.predict(X_TR, save_gradients=False, save_states=True)
ip_reservoir.plot_neural_activity()

# %%
bimodal_reservoir.rescale_weights(0.25)

# %%
bimodal_reservoir.pre_train(X_TR, 0, 0)
bimodal_reservoir.predict(X_TR, save_gradients=False, save_states=True)
bimodal_reservoir.plot_neural_activity()

# %%
bimodal_reservoir.KL(X_TR[100:None])
# Out:
# tensor(0.0760)
