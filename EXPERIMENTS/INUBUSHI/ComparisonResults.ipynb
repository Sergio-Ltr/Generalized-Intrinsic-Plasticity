# %%
import pandas as pd

# %%
result_df = pd.read_csv("./INUBUSHI-DIST-COMP_{-1}.csv")

# %%
df_mean()
# Out:
#     Unnamed: 0     Model Name    N  Model Index Aggregation           MSE  \
# 0            0        Vanilla   50          0.0        Mean  4.463143e-05
# 1            2       Gaussian   50          1.0        Mean  1.035434e-04
# 2            4   Hard Bimodal   50          2.0        Mean  1.313056e-05
# 3            8  Soft Trimodal   50          3.0        Mean  6.779889e-05
# 4           10  Edgy trimodal   50          4.0        Mean  6.467100e-05
# 5            0        Vanilla  100          0.0        Mean  1.372038e-05
# 6            2       Gaussian  100          1.0        Mean  5.835754e-05
# 7            4   Hard Bimodal  100          2.0        Mean  3.240724e-07
# 8            8  Soft Trimodal  100          3.0        Mean  4.126593e-05
# 9           10  Edgy trimodal  100          4.0        Mean  3.839164e-05
# 10           0        Vanilla  150          0.0        Mean  7.052863e-06
# 11           2       Gaussian  150          1.0        Mean  4.597877e-05
# ...

# %%
result_df.reset_index(drop=True)
# Out:
#     Unnamed: 0     Model Name    N  Model Index Aggregation           MSE  \
# 0            0        Vanilla   50          0.0        Mean  4.463143e-05
# 1            1        Vanilla   50          0.0         Std  1.891239e-05
# 2            2       Gaussian   50          1.0        Mean  1.035434e-04
# 3            3       Gaussian   50          1.0         Std  2.677714e-05
# 4            4   Hard Bimodal   50          2.0        Mean  1.313056e-05
# 5            5   Hard Bimodal   50          2.0         Std  1.226726e-05
# 6            8  Soft Trimodal   50          3.0        Mean  6.779889e-05
# 7            9  Soft Trimodal   50          3.0         Std  2.777909e-05
# 8           10  Edgy trimodal   50          4.0        Mean  6.467100e-05
# 9           11  Edgy trimodal   50          4.0         Std  1.291106e-05
# 10           0        Vanilla  100          0.0        Mean  1.372038e-05
# 11           1        Vanilla  100          0.0         Std  8.687848e-06
# ...

# %%
# Split DataFrame into even and odd rows
df_mean = result_df[result_df.index % 2 == 0].reset_index(drop=True)
df_std = result_df[result_df.index % 2 != 0].reset_index(drop=True)

# %%
mask_names = ["Vanilla", "Gaussian", "Hard Bimodal", "Soft Trimodal", "Edgy trimodal" ]

# %% [markdown]
# ## MSE PLOT

# %%
custom_palette = sns.color_palette("Set1")

# %%
custom_palette
# Out:
# [(0.8941176470588236, 0.10196078431372549, 0.10980392156862745),
#  (0.21568627450980393, 0.49411764705882355, 0.7215686274509804),
#  (0.30196078431372547, 0.6862745098039216, 0.2901960784313726),
#  (0.596078431372549, 0.3058823529411765, 0.6392156862745098),
#  (1.0, 0.4980392156862745, 0.0),
#  (1.0, 1.0, 0.2),
#  (0.6509803921568628, 0.33725490196078434, 0.1568627450980392),
#  (0.9686274509803922, 0.5058823529411764, 0.7490196078431373),
#  (0.6, 0.6, 0.6)]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming df is your DataFrame
# Example DataFrame structure:
# df = pd.DataFrame({'N': ..., 'MSE_mean': ..., 'MSE_std': ..., 'model_index': ...})

# Set the style if needed
sns.set(style="whitegrid")

# Adjust figure size if needed
plt.figure(figsize=(10, 6))

# Use Seaborn's lineplot() with error bars to plot the mean values and standard deviation
sns.lineplot(x='N', y='MSE', hue=df_mean.columns[3], data=df_mean, marker='o', palette=custom_palette[0:5])
plt.errorbar(x=df_std['N'], y=df_mean['MSE'], yerr=df_std['MSE'], fmt='none', capsize=5, c='gray')

plt.title('Model Performance vs. Complexity')
plt.xlabel('Complexity (N)')
plt.ylabel('MSE (Performance)')
plt.legend(title='Model Index', labels=mask_names)

plt.show()

# %% [markdown]
# ## DELTA PHI PLOT

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming df is your DataFrame
# Example DataFrame structure:
# df = pd.DataFrame({'N': ..., 'MSE_mean': ..., 'MSE_std': ..., 'model_index': ...})

# Set the style if needed
sns.set(style="whitegrid")

# Adjust figure size if needed
plt.figure(figsize=(10, 6))

# Use Seaborn's lineplot() with error bars to plot the mean values and standard deviation
sns.lineplot(x='N', y='DeltaPhi', hue=df_mean.columns[3], data=df_mean, marker='o', palette=custom_palette[0:5])
plt.errorbar(x=df_std['N'], y=df_mean['DeltaPhi'], yerr=df_std['DeltaPhi'], fmt='none', capsize=5, c='gray')

plt.title('Non Linearity vs. Complexity')
plt.xlabel('Number of Units (N)')
plt.ylabel('DeltaPhi (Non Linearity)')
plt.legend(title='Model Index', labels=mask_names)

plt.show()
