# %%
import sys  
sys.path.insert(1, './../../../../ESN-IP/SOURCES/.')

import random

random.seed(10)

# %%
from Configurations import ReservoirConfiguration
from Configurations import IPReservoirConfiguration
from IPMask import IPMask
from DATA import MG17
from Metrics import *

# %%
from Configuartions import *

# %%
N = 20

# %%
initial_config = ReservoirConfiguration(N=N, bias=False, input_scaling=1, Wu_sparsity=0, Wh_sparsity=0, desired_rho=0.8, name="Vanilla 2" )

# %%
configs = [
    IPReservoirConfiguration(initial_config, IPMask.gaussian(N), eta=0.0000025, epochs=5, name="Gaussian"),
    
    #IPReservoirConfiguration(initial_config, IPMask.bimodal(N, mu=0.92, std=0.15), eta=0.0000025, epochs=5,  name="Bimodal"),,m
    #IPReservoirConfiguration(initial_config, IPMask.trimodal(N, mu=0.92, std_bim=0.25,), eta=0.0000025, epochs=10, name="Edged Trimodal"),
    #IPReservoirConfiguration(initial_config, IPMask.trimodal(N, linear_rate=3/5), eta=0.00000125, epochs=10, name="Linear Trimodal"),
    #IPReservoirConfiguration(initial_config, IPMask.quadrimodal(N), eta=0.0000025, epochs=5,  name="Quadrimodal"),
    ReservoirConfiguration(N=N, desired_rho=0.96, name="Vanilla"),
]

# %%
from Evaluator import Evaluator

results = Evaluator(path=".", experiment_name="Optimal Memory Initial Config").evaluate_multiple(configs, data = MG17(percentages=[80, 0, 20]), repetitions=1 )
# Out:
# Reservoir warmed up with the first 100 time steps
# Reservoir warmed up with the first 100 time steps

# %%
results
# Out:
#   Model Name  Model Index Aggregation           MSE     NRMSE       Rho  \
# 0   Gaussian          0.0        Mean  5.881839e-07  0.158328  0.875425
# 1   Gaussian          0.0         Std  0.000000e+00  0.000000  0.000000
# 2    Vanilla          1.0        Mean  9.744464e-07  0.203788  0.959999
# 3    Vanilla          1.0         Std  0.000000e+00  0.000000  0.000000
#
#        MLLE  DeltaPhi        MC      Neff
# 0 -0.043073  0.093626  6.748850  2.661027
# 1  0.000000  0.000000  0.000000  0.000000
# 2 -0.050937  0.068263  9.082959  3.296857
# 3  0.000000  0.000000  0.000000  0.000000

# %%
initial_configs = ReservoirHyperparamSpace(unit_range=[50], input_scaling_range=[0.25, 0.5, 1], bu_scaling_range=[1, 0.5], bh_scaling_range=[0])

# %%
configs = [IPReservoirConfiguration(config, eta=0.0000025, epochs=10, mask=IPMask.trimodal(50, mu=0.92, std_bim=0.25,),  name="Edged Trimodal") for config in initial_configs.get_configs()]

# %%
configs
# Out:
# [<IPReservoir.IPReservoirConfiguration at 0x2b2a1e7e550>,
#  <IPReservoir.IPReservoirConfiguration at 0x2b2f56c7d00>,
#  <IPReservoir.IPReservoirConfiguration at 0x2b2f56d23a0>,
#  <IPReservoir.IPReservoirConfiguration at 0x2b2f56d8a00>,
#  <IPReservoir.IPReservoirConfiguration at 0x2b2f56e00a0>,
#  <IPReservoir.IPReservoirConfiguration at 0x2b2f56e6700>,
#  <IPReservoir.IPReservoirConfiguration at 0x2b2f56ecd60>,
#  <IPReservoir.IPReservoirConfiguration at 0x2b2f56f4400>,
#  <IPReservoir.IPReservoirConfiguration at 0x2b2f56faa60>,
#  <IPReservoir.IPReservoirConfiguration at 0x2b2f5702100>,
#  <IPReservoir.IPReservoirConfiguration at 0x2b2f5708760>,
#  <IPReservoir.IPReservoirConfiguration at 0x2b2f570fdc0>,
#  <IPReservoir.IPReservoirConfiguration at 0x2b2f5717460>,
#  <IPReservoir.IPReservoirConfiguration at 0x2b2f571eac0>,
#  <IPReservoir.IPReservoirConfiguration at 0x2b2f5727160>,
#  <IPReservoir.IPReservoirConfiguration at 0x2b2f572c7c0>,
#  <IPReservoir.IPReservoirConfiguration at 0x2b2f5732e20>,
#  <IPReservoir.IPReservoirConfiguration at 0x2b2f573a4c0>,
#  <IPReservoir.IPReservoirConfiguration at 0x2b2f5740b20>,
#  <IPReservoir.IPReservoirConfiguration at 0x2b2f574a1c0>,
#  <IPReservoir.IPReservoirConfiguration at 0x2b2f574f820>,
#  <IPReservoir.IPReservoirConfiguration at 0x2b2f5755eb0>,
#  <IPReservoir.IPReservoirConfiguration at 0x2b2f575e550>,
#  <IPReservoir.IPReservoirConfiguration at 0x2b2f5763bb0>,
#  <IPReservoir.IPReservoirConfiguration at 0x2b2f576d250>,
#  <IPReservoir.IPReservoirConfiguration at 0x2b2f57748b0>,
#  <IPReservoir.IPReservoirConfiguration at 0x2b2f5779f10>]

# %%
#results = Evaluator(path=".", experiment_name="Rough gird search attempt").evaluate_multiple(configs, data = MG17(percentages=[80, 0, 20]), repetitions=1, estrinsic_metrics=[MSE()],intrinsic_metrics=[Rho()] )

# %%
#results
# Out:
#         Model Name  Model Index Aggregation           MSE       Rho
# 0   Edged Trimodal          0.0        Mean  6.816667e-07  0.590554
# 1   Edged Trimodal          0.0         Std  0.000000e+00  0.000000
# 2   Edged Trimodal          1.0        Mean  4.137295e-07  0.590554
# 3   Edged Trimodal          1.0         Std  0.000000e+00  0.000000
# 4   Edged Trimodal          2.0        Mean  6.894856e-07  0.590555
# 5   Edged Trimodal          2.0         Std  0.000000e+00  0.000000
# 6   Edged Trimodal          3.0        Mean  2.973218e-07  0.590553
# 7   Edged Trimodal          3.0         Std  0.000000e+00  0.000000
# 8   Edged Trimodal          4.0        Mean  4.669525e-07  0.590553
# 9   Edged Trimodal          4.0         Std  0.000000e+00  0.000000
# 10  Edged Trimodal          5.0        Mean  5.509309e-07  0.590557
# 11  Edged Trimodal          5.0         Std  0.000000e+00  0.000000
# 12  Edged Trimodal          6.0        Mean  3.559275e-07  0.590555
# 13  Edged Trimodal          6.0         Std  0.000000e+00  0.000000
# 14  Edged Trimodal          7.0        Mean  5.287512e-07  0.590554
# 15  Edged Trimodal          7.0         Std  0.000000e+00  0.000000
# 16  Edged Trimodal          8.0        Mean  2.894047e-07  0.590555
# 17  Edged Trimodal          8.0         Std  0.000000e+00  0.000000
# 18  Edged Trimodal          9.0        Mean  2.258949e-07  0.885828
# 19  Edged Trimodal          9.0         Std  0.000000e+00  0.000000
# 20  Edged Trimodal         10.0        Mean  2.143507e-07  0.885831
# 21  Edged Trimodal         10.0         Std  0.000000e+00  0.000000
# 22  Edged Trimodal         11.0        Mean  3.184435e-07  0.885830
# 23  Edged Trimodal         11.0         Std  0.000000e+00  0.000000
# 24  Edged Trimodal         12.0        Mean  2.604833e-07  0.885829
# 25  Edged Trimodal         12.0         Std  0.000000e+00  0.000000
# 26  Edged Trimodal         13.0        Mean  2.083622e-07  0.885831
# 27  Edged Trimodal         13.0         Std  0.000000e+00  0.000000
# 28  Edged Trimodal         14.0        Mean  3.364423e-07  0.885832
# 29  Edged Trimodal         14.0         Std  0.000000e+00  0.000000
# 30  Edged Trimodal         15.0        Mean  2.145754e-07  0.885829
# 31  Edged Trimodal         15.0         Std  0.000000e+00  0.000000
# 32  Edged Trimodal         16.0        Mean  2.197830e-07  0.885831
# 33  Edged Trimodal         16.0         Std  0.000000e+00  0.000000
# 34  Edged Trimodal         17.0        Mean  3.359784e-07  0.885830
# 35  Edged Trimodal         17.0         Std  0.000000e+00  0.000000
# 36  Edged Trimodal         18.0        Mean  1.557738e-07  1.122052
# 37  Edged Trimodal         18.0         Std  0.000000e+00  0.000000
# 38  Edged Trimodal         19.0        Mean  3.295411e-07  1.122052
# 39  Edged Trimodal         19.0         Std  0.000000e+00  0.000000
# 40  Edged Trimodal         20.0        Mean  1.685244e-07  1.122051
# 41  Edged Trimodal         20.0         Std  0.000000e+00  0.000000
# 42  Edged Trimodal         21.0        Mean  2.410214e-07  1.122053
# 43  Edged Trimodal         21.0         Std  0.000000e+00  0.000000
# 44  Edged Trimodal         22.0        Mean  2.112363e-07  1.122055
# 45  Edged Trimodal         22.0         Std  0.000000e+00  0.000000
# 46  Edged Trimodal         23.0        Mean  2.262658e-07  1.122052
# 47  Edged Trimodal         23.0         Std  0.000000e+00  0.000000
# 48  Edged Trimodal         24.0        Mean  1.759985e-07  1.122051
# 49  Edged Trimodal         24.0         Std  0.000000e+00  0.000000
# 50  Edged Trimodal         25.0        Mean  5.970791e-07  1.122055
# 51  Edged Trimodal         25.0         Std  0.000000e+00  0.000000
# 52  Edged Trimodal         26.0        Mean  3.147641e-07  1.122051
# 53  Edged Trimodal         26.0         Std  0.000000e+00  0.000000

# %%
for i in [10,13,18,20,24]:
    print(i, configs[i].description())
# Out:
# 10 Target: Trimodal - rate:0.5555555555555556 - mu: 0.92 - std_lin: 0.2 - std_bim:0.25 |  Eta: 2.5e-06 - Epochs: 10 | Initial state:  Units: 50, Input scaling: 0.25, Rho: 0.75 - Biased - Bias scaling: (0.5, 0) - Sparsity: (0, 0)
# 13 Target: Trimodal - rate:0.5555555555555556 - mu: 0.92 - std_lin: 0.2 - std_bim:0.25 |  Eta: 2.5e-06 - Epochs: 10 | Initial state:  Units: 50, Input scaling: 0.5, Rho: 0.75 - Biased - Bias scaling: (0.5, 0) - Sparsity: (0, 0)
# 18 Target: Trimodal - rate:0.5555555555555556 - mu: 0.92 - std_lin: 0.2 - std_bim:0.25 |  Eta: 2.5e-06 - Epochs: 10 | Initial state:  Units: 50, Input scaling: 0.25, Rho: 0.95 - Biased - Bias scaling: (1, 0) - Sparsity: (0, 0)
# 20 Target: Trimodal - rate:0.5555555555555556 - mu: 0.92 - std_lin: 0.2 - std_bim:0.25 |  Eta: 2.5e-06 - Epochs: 10 | Initial state:  Units: 50, Input scaling: 0.25, Rho: 0.95 - Unbiased - Bias scaling: (0, 0) - Sparsity: (0, 0)
# 24 Target: Trimodal - rate:0.5555555555555556 - mu: 0.92 - std_lin: 0.2 - std_bim:0.25 |  Eta: 2.5e-06 - Epochs: 10 | Initial state:  Units: 50, Input scaling: 1, Rho: 0.95 - Biased - Bias scaling: (1, 0) - Sparsity: (0, 0)
